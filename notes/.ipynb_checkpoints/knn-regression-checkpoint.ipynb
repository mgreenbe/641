# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsRegressor as knn

# %%
x = np.linspace(0, 1, 10)
xx = np.linspace(0, 1, 100)
y = x**4 + 0.075*np.random.randn(len(x))

# %%
plt.plot(x, y)

# %%
R = knn(n_neighbors=3)

# %% [raw]
# x
