# %% [markdown]
# ## Decision trees and random forests

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier
import pandas
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# Acquaint yourself with the data in `spambase.csv`.

# %%
data = pandas.read_csv("spambase.csv")
values = data.values # Turn a pandas dataframe into a numpy matrix
X = values[:, :57] # features
y = values[:, 57] # target

# %% [markdown]
# Separate the data into training and test sets.
# Train a **decision tree classifier** (`DecisionTreeClassifier`) on the training test.
# Compute the accuracy on the test set.
# Plot feature importances.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
R = DecisionTreeClassifier()
R.fit(X_train, y_train)
y_predict = R.predict(X_test)
I = y_predict == y_test
accuracy = sum(I)/len(y_test)
print(f"Testing Accuracy: {accuracy}")
# Out:
# Testing Accuracy: 0.9061685490877498

# %% [markdown]
# Train a **bagging classifier** (`BaggingClassifier`) on the training test.
# Compute the accuracy on the test set.
# Plot feature importances.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
R = BaggingClassifier(DecisionTreeClassifier(), n_estimators=50)
R.fit(X_train, y_train)
y_predict = R.predict(X_test)
I = y_predict == y_test
accuracy = sum(I)/len(y_test)
print(f"Testing Accuracy: {accuracy}")
# Out:
# Testing Accuracy: 0.947871416159861

# %% [markdown]
# Train a **random forest classifier** (`RandomForestClassifier`) on the training test.
# Compute the accuracy on the test set.
# Plot feature importances.

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)
R = RandomForestClassifier(n_estimators=100)
R.fit(X_train, y_train)
y_predict = R.predict(X_test)
I = y_predict == y_test
accuracy = sum(I)/len(y_test)
print(f"Testing Accuracy: {accuracy}")
# Out:
# Testing Accuracy: 0.944396177237185

# %%
plt.figure(figsize=(18, 12))
fis = R.feature_importances_
plt.barh(list(data)[:-1], fis)
plt.show()
